# %%
import cupy as cp
from cupyx.scipy.ndimage import zoom
import glob
import nibabel as nib
import ipympl
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def create_bounding_box_roi(mask_img):
    """
    Creates a bounding box ROI from a Nifti mask image.

    Parameters:
    - mask_img (nibabel.Nifti1Image): The Nifti mask image.

    Returns:
    - bbox_roi_img (nibabel.Nifti1Image): The Nifti image of the bounding box ROI.
    """
    # Load the mask data
    mask_data = mask_img.get_fdata()
    
    # Find the indices of non-zero elements (the ROI)
    non_zero_indices = np.argwhere(mask_data>0.5)
    
    # Determine the minimum and maximum bounds along each axis
    min_bounds = non_zero_indices.min(axis=0) - 1
    max_bounds = non_zero_indices.max(axis=0) + 1  # Add 1 because slices are exclusive on the upper bound
    
    # Extract the bounding box region
    bbox_data = np.zeros(mask_data.shape)
    bbox_data[min_bounds[0]:max_bounds[0], min_bounds[1]:max_bounds[1], min_bounds[2]:max_bounds[2]] = 1
    
    # Calculate the new affine transformation for the bounding box ROI
    new_affine = mask_img.affine.copy()
    new_affine[:3, 3] += min_bounds * mask_img.header.get_zooms()[:3]
    
    # Create a new Nifti image for the bounding box ROI
    bbox_roi_img = nib.Nifti1Image(bbox_data, mask_img.affine, mask_img.header)
    
    return bbox_roi_img

# %%
path_data = glob.glob('/mnt/data/psteinmetz/neotex/to_process/*')
for data in path_data:
    print(data)
    mask = glob.glob(data + '/RoiVolume/New_C1_volume_resampled_NN.nii.gz')
    image = glob.glob(data + '/RawVolume/substracted_resampled_bspline_zscore_without_tumor.nii.gz')
    if mask == [] or image == []:
        print('here')
        pass
    else:
        mask_img = nib.load(mask[0])
        bbox_roi_img = create_bounding_box_roi(mask_img)
        print(np.sum(mask_img.get_fdata()))
        print(np.sum(bbox_roi_img.get_fdata()))
        nib.save(bbox_roi_img, data + '/RoiVolume/New_bb_resampled_NN.nii.gz')
# Out:
# /mnt/data/psteinmetz/neotex/to_process/136
# 15716.403854527882
# 44608.0
# /mnt/data/psteinmetz/neotex/to_process/117
# here
# /mnt/data/psteinmetz/neotex/to_process/129
# 2610.8755125713697
# 7600.0
# /mnt/data/psteinmetz/neotex/to_process/133
# 23062.443367785505
# 74620.0
# /mnt/data/psteinmetz/neotex/to_process/142
# 36277.14955846758
# 87516.0
# /mnt/data/psteinmetz/neotex/to_process/134
# here
# /mnt/data/psteinmetz/neotex/to_process/152
# 30125.312089010087
# 85054.0
# /mnt/data/psteinmetz/neotex/to_process/116
# here
# /mnt/data/psteinmetz/neotex/to_process/123
# 26469.442752853975
# 60458.0
# /mnt/data/psteinmetz/neotex/to_process/140
# 6102.635335280863
# 19440.0
# /mnt/data/psteinmetz/neotex/to_process/109
# 2300.1112732549504
# 5670.0
# /mnt/data/psteinmetz/neotex/to_process/150
# 3276.532213149518
# 13860.0
# /mnt/data/psteinmetz/neotex/to_process/118
# 17504.387501738336
# 41184.0
# /mnt/data/psteinmetz/neotex/to_process/155
# 19216.719138653225
# 43956.0
# /mnt/data/psteinmetz/neotex/to_process/108
# 5565.031599216879
# 14850.0
# /mnt/data/psteinmetz/neotex/to_process/151
# 3002.350610881984
# 13608.0
# /mnt/data/psteinmetz/neotex/to_process/153
# 14050.74966032889
# 45838.0
# /mnt/data/psteinmetz/neotex/to_process/111
# 4849.914350341415
# 11500.0
# /mnt/data/psteinmetz/neotex/to_process/144
# 4353.2761338867085
# 14300.0
# /mnt/data/psteinmetz/neotex/to_process/128
# here
# /mnt/data/psteinmetz/neotex/to_process/149
# 3558.283176653272
# 13754.0
# /mnt/data/psteinmetz/neotex/to_process/146
# 4822.142137281378
# 14674.0
# /mnt/data/psteinmetz/neotex/to_process/124
# 10431.540631926811
# 44118.0
# /mnt/data/psteinmetz/neotex/to_process/145
# 5178.58390685621
# 20625.0
# /mnt/data/psteinmetz/neotex/to_process/154
# 2899.6538114636924
# 7820.0
# /mnt/data/psteinmetz/neotex/to_process/138
# 7083.490367250834
# 18000.0
# /mnt/data/psteinmetz/neotex/to_process/141
# 15357.434218399763
# 52972.0
# /mnt/data/psteinmetz/neotex/to_process/130
# 2340.329264300538
# 12138.0
# /mnt/data/psteinmetz/neotex/to_process/135
# 3232.1207558617207
# 7956.0
# /mnt/data/psteinmetz/neotex/to_process/147
# 145979.25034591992
# 563472.0
# /mnt/data/psteinmetz/neotex/to_process/143
# here
# /mnt/data/psteinmetz/neotex/to_process/127
# here
# /mnt/data/psteinmetz/neotex/to_process/110
# 256697.57248428024
# 974700.0
# /mnt/data/psteinmetz/neotex/to_process/131
# 18450.625685659106
# 55685.0
# /mnt/data/psteinmetz/neotex/to_process/148
# 16774.827758291965
# 68634.0
# /mnt/data/psteinmetz/neotex/to_process/113
# 2870.2415816766093
# 7056.0
# /mnt/data/psteinmetz/neotex/to_process/137
# 4369.222814941794
# 11934.0
# /mnt/data/psteinmetz/neotex/to_process/125
# 2834.2328714699274
# 9880.0
# /mnt/data/psteinmetz/neotex/to_process/115
# 23254.96724588488
# 57387.0
# /mnt/data/psteinmetz/neotex/to_process/122
# 11573.14539728764
# 36630.0
# /mnt/data/psteinmetz/neotex/to_process/106
# 7624.568227721109
# 31248.0
# /mnt/data/psteinmetz/neotex/to_process/107
# 19142.4569411631
# 90288.0
# /mnt/data/psteinmetz/neotex/to_process/112
# 1317.4063407430654
# 4096.0
# /mnt/data/psteinmetz/neotex/to_process/156
# 8389.280557420148
# 44616.0
# /mnt/data/psteinmetz/neotex/to_process/114
# 72773.0
# 498456.0
# /mnt/data/psteinmetz/neotex/to_process/121
# 13780.071067801535
# 38080.0
# /mnt/data/psteinmetz/neotex/to_process/139
# 11575.51683762777
# 25296.0
# /mnt/data/psteinmetz/neotex/to_process/119
# here
# /mnt/data/psteinmetz/neotex/to_process/11
# 29654.046686240923
# 77572.0
# /mnt/data/psteinmetz/neotex/to_process/126
# 16384.379304711765
# 41650.0

# %%
path_data

# %%
masks = glob.glob(path_data + '\*'New_C1_volume_resampled_NN.nii.gz')
